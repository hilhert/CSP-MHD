# %%
# %run sim_sequence.py
# Out:
# Using device: cpu
# Atten mode received! I'm createing attention style hidden layer!
# 创建新模型
# 参数量: 25,958
# ...
# Evaluating:  12%|█▎        | 4/32 [00:00<00:01, 16.45it/s]
# [Debug] Input: <SOS>1 + 2 - 2 mod 3 =
# [Debug] Pred : 2 - 1 + 2 mod 3 = 1
# [Debug] Target: 1 + 2 - 2 mod 3 = 1
# pred_ids[0]: [2, 13, 11, 13, 1, 13, 10, 13, 2, 13, 19, 13, 3, 13, 12, 13, 1, 17, 17, 10]
# ----------------------------------------
# [Debug] Input: <SOS>0 + 1 mod 3 =
# [Debug] Pred : 0 + 1 mod 3 = 1
# [Debug] Target: 0 + 1 mod 3 = 1
# pred_ids[0]: [2, 13, 11, 13, 1, 13, 10, 13, 2, 13, 19, 13, 3, 13, 12, 13, 1, 17, 17, 10]
# ----------------------------------------
# [Debug] Input: <SOS>1 + 1 + 2 mod 3 =
# [Debug] Pred : 1 + 1 + 1 mod 3 = 2
# [Debug] Target: 1 + 1 + 2 mod 3 = 1
# pred_ids[0]: [2, 13, 11, 13, 1, 13, 10, 13, 2, 13, 19, 13, 3, 13, 12, 13, 1, 17, 17, 10]
# ----------------------------------------
# [Debug] Input: <SOS>(0 - 2) mod 3 =
# [Debug] Pred : (2 - 0) mod 3 = 1
# ...
