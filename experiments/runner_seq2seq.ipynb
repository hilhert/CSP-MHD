# %%
# %run sim_sequence.py
# Out:
# Using device: cuda
# Linear Tree Atten mode received! I'm createing tree attention style hidden layer!
# 创建新模型
# 参数量: 208,224
# ...
# Evaluating: 100%|██████████| 313/313 [00:06<00:00, 51.24it/s]
# Epoch 1: Loss=0.5570, Acc=0.0890
# ...
# Evaluating: 100%|██████████| 313/313 [00:06<00:00, 51.05it/s]
# Epoch 2: Loss=0.2103, Acc=0.1202
# ...
# Evaluating: 100%|██████████| 313/313 [00:06<00:00, 49.70it/s]
# Epoch 3: Loss=0.1774, Acc=0.1344
# ...
# Evaluating: 100%|██████████| 313/313 [00:06<00:00, 49.14it/s]
# Epoch 4: Loss=0.1603, Acc=0.1623
# ...
# Evaluating: 100%|██████████| 313/313 [00:06<00:00, 49.60it/s]
# Epoch 5: Loss=0.1467, Acc=0.1915
# Training:   4%|▍         | 60/1563 [00:05<02:23, 10.49it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Documents/my_notebooks/CSP/experiments/sim_sequence.py:132
#     115 '''
#     116     losses, f1s,accs,grad_norms = train_model(
# ...
