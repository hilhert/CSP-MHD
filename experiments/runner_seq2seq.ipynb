# %%
# %run sim_sequence.py
# Out:
# Using device: cuda
#  sos_idx:16
#  pad_idx:18
#  eos_idx:17
# Loading existence model: /home/lxh/Documents/my_notebooks/CSP_MHD/experiments/symseq/symseq_atten_rbf_complete.pt
# numel of params: 195,601
# ...
# Evaluating:   1%|          | 2/313 [00:00<00:26, 11.62it/s]
# [Debug] Input: <SOS>((0 - 0) - 2 + 0) mod 9 =
# [Debug] Pred : 7 repeat ((0 - 0) - 2 + (0 - 2)) mod
# [Debug] Target: 7 repeat ((0 - 0) - 2 + 0) mod 9 = 7
# pred_ids[0]: [7, 20, 14, 14, 0, 13, 11, 13, 0, 15, 13, 11, 13, 2, 13, 10, 13, 14, 0, 13, 11, 13, 2, 15, 15, 13, 19, 13, 9, 13, 12, 13, 7, 17, 14, 5, 13, 5, 13, 5]
# ----------------------------------------
# [Debug] Input: <SOS>((4 + 6)) mod 9 =
# [Debug] Pred : 6 repeat ((4 + 6)) mod 9 = 6
# [Debug] Target: 1 repeat ((4 + 6)) mod 9 = 1
# pred_ids[0]: [7, 20, 14, 14, 0, 13, 11, 13, 0, 15, 13, 11, 13, 2, 13, 10, 13, 14, 0, 13, 11, 13, 2, 15, 15, 13, 19, 13, 9, 13, 12, 13, 7, 17, 14, 5, 13, 5, 13, 5]
# ----------------------------------------
# ...

# %%
help(json.dump)
