# %%
# %run sim_sequence.py
# Out:
# Using device: cuda
# 创建新模型
# 参数量: 208,231
# ...
# Evaluating:   3%|▎         | 10/313 [00:00<00:06, 46.71it/s]
# [Debug] Input: <SOS>((8 + 1 - 4)) mod 9 =
# [Debug] Pred : ((8 - 1) + 4) mod 9 =
# [Debug] Target: ((8 + 1 - 4)) mod 9 = 5
# pred_ids[0]: [14, 14, 8, 13, 11, 13, 1, 15, 13, 10, 13, 4, 15, 13, 19, 13, 9, 13, 12, 13]
# ----------------------------------------
# [Debug] Input: <SOS>(3 + 4 - 0) mod 9 =
# [Debug] Pred : (3 + 4 - 0) mod 9 = 7
# [Debug] Target: (3 + 4 - 0) mod 9 = 7
# pred_ids[0]: [14, 14, 8, 13, 11, 13, 1, 15, 13, 10, 13, 4, 15, 13, 19, 13, 9, 13, 12, 13]
# ----------------------------------------
# [Debug] Input: <SOS>((0 + 0 - 0)) mod 9 =
# [Debug] Pred : ((0 + 0 - 0)) mod 9 =
# [Debug] Target: ((0 + 0 - 0)) mod 9 = 0
# pred_ids[0]: [14, 14, 8, 13, 11, 13, 1, 15, 13, 10, 13, 4, 15, 13, 19, 13, 9, 13, 12, 13]
# ----------------------------------------
# [Debug] Input: <SOS>(((4 + 4) - (6 + 7))) mod 9 =
# [Debug] Pred : (((4 + (6 - 4) + 7))
# ...
