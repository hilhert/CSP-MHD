# %%
#%run sim_sequence.py
# %run sim_sequence-new.py
# Out:
# Using device: cuda
# Multi head rbf Atten mode received! I'm createing attention style hidden layer with mhead!
# Multi head rbf Atten mode received! I'm createing attention style hidden layer with mhead!
# Multi head rbf Atten mode received! I'm createing attention style hidden layer with mhead!
# Complex mamba with rotation mode received! I'm createing CSP style hidden layer!
# Multi head rbf Atten mode received! I'm createing attention style hidden layer with mhead!
# Multi head rbf Atten mode received! I'm createing attention style hidden layer with mhead!
# Multi head rbf Atten mode received! I'm createing attention style hidden layer with mhead!
# Complex mamba with rotation mode received! I'm createing CSP style hidden layer!
# Multi head rbf Atten mode received! I'm createing attention style hidden layer with mhead!
# Multi head rbf Atten mode received! I'm createing attention style hidden layer with mhead!
# ...
