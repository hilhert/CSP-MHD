# %%
# %run sim_sequence.py
# Out:
# Using device: cuda
#  sos_idx:16
#  pad_idx:18
#  eos_idx:17
# Loading existence model: /home/lxh/Documents/my_notebooks/CSP_MHD/experiments/symseq/symseq_atten_rbf_complete.pt
# numel of params: 195,602
# Optimizer state restored (including adjusted learning rate).
# ...
# Evaluating:   1%|          | 4/400 [00:00<00:25, 15.80it/s]
# [Debug] Input: <SOS>(0 - ((0 + 5) - 7)) mod 9 =
# [Debug] Pred : 0 repeat (0 - (0 + (0 + 0))) mod 9 = 0
# [Debug] Target: 2 repeat (0 - ((0 + 5) - 7)) mod 9 = 2
# pred_ids[0]: [0, 20, 14, 0, 13, 11, 13, 14, 0, 13, 10, 13, 14, 0, 13, 10, 13, 0, 15, 15, 15, 13, 19, 13, 9, 13, 12, 13, 0, 17, 0, 17, 0, 17, 17, 0, 17, 12, 12, 0]
# ----------------------------------------
# [Debug] Input: <SOS>(-4 - (-4 + 3)) mod 9 =
# [Debug] Pred : 4 repeat (-4 - (-4 + -4)) mod 9 = 4
# [Debug] Target: 6 repeat (-4 - (-4 + 3)) mod 9 = 6
# ...
