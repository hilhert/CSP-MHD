# %%
# %run sim_sequence.py
# Out:
# Using device: cuda
#  sos_idx:16
#  pad_idx:18
#  eos_idx:17
# Loading existence model: /home/lxh/Documents/my_notebooks/CSP_MHD/experiments/symseq/symseq_atten_rbf_complete.pt
# numel of params: 195,601
# Optimizer state restored (including adjusted learning rate).
# Training:  58%|█████▊    | 910/1563 [04:47<03:20,  3.26it/s]
