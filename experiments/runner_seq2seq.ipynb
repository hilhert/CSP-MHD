# %%
# %run sim_sequence.py
# Out:
# Using device: cuda
#  sos_idx:16
#  pad_idx:18
#  eos_idx:17
# Loading existence model: /home/lxh/Documents/my_notebooks/CSP_MHD/experiments/symseq/symseq_atten_rbf_complete.pt
# numel of params: 195,601
# Optimizer state restored (including adjusted learning rate).
# ...
# Evaluating:   1%|▏         | 4/313 [00:00<00:20, 15.08it/s]
# [Debug] Input: <SOS>((3 + -2)) mod 9 =
# [Debug] Pred : 5 repeat ((3 + -2)) mod 9 = 5
# [Debug] Target: 1 repeat ((3 + -2)) mod 9 = 1
# pred_ids[0]: [5, 20, 14, 14, 3, 13, 10, 13, 11, 2, 15, 15, 13, 19, 13, 9, 13, 12, 13, 5, 17, 14, 7, 0, 14, 11, 7, 10, 13, 11, 8, 15, 15, 13, 19, 13, 9, 13, 12, 13]
# ----------------------------------------
# [Debug] Input: <SOS>(-3) mod 9 =
# [Debug] Pred : 6 repeat (-3) mod 9 = 6
# [Debug] Target: 6 repeat (-3) mod 9 = 6
# pred_ids[0]: [5, 20, 14, 14, 3, 13, 10, 13, 11, 2, 15, 15, 13, 19, 13, 9, 13, 12, 13, 5, 17, 14, 7, 0, 14, 11, 7, 10, 13, 11, 8, 15, 15, 13, 19, 13, 9, 13, 12, 13]
# ...
