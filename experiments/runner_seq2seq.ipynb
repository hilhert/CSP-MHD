# %%
# %run sim_sequence.py
# Out:
# Using device: cuda
# No known mode explicted! Draw back to relax mode with shared weights and per domain activate!
# 创建新模型
# 参数量: 82,893
# ...
# Evaluating:   1%|          | 2/313 [00:00<00:49,  6.28it/s]
# [Debug] Input: <SOS>((1 - ((5 + 4) + 0))) mod 9 =
# [Debug] Pred : 0 repeat ((0 - 0) + 0) mod 9 = 0 0 0 0
# [Debug] Target: 1 repeat ((1 - ((5 + 4) + 0))) mod 9 = 1
# pred_ids[0]: [0, 20, 14, 14, 0, 13, 11, 13, 0, 15, 13, 10, 13, 0, 15, 13, 19, 13, 9, 13, 12, 13, 0, 17, 13, 0, 17, 13, 0, 17, 13, 0, 15, 13, 19, 13, 9, 13, 12, 13]
# ----------------------------------------
# [Debug] Input: <SOS>((((4 + 6) + 4) - 6)) mod 9 =
# [Debug] Pred : 0 repeat ((0 - 0) + 0) mod 9 = 0 0 0 0
# [Debug] Target: 8 repeat ((((4 + 6) + 4) - 6)) mod 9 = 8
# pred_ids[0]: [0, 20, 14, 14, 0, 13, 11, 13, 0, 15, 13, 10, 13, 0, 15, 13, 19, 13, 9, 13, 12, 13, 0, 17, 13, 0, 17, 13, 0, 17, 13, 0, 15, 13, 19, 13, 9, 13, 12, 13]
# ----------------------------------------
# ...

# %%
import json

a = {"a":["a","b"]}
json_data = json.dumps(a, default=lambda o: o.__dict__, indent=4)
with open("test.json",'w') as t:
    t.write(json_data)
with open("test.json","r") as json_data:
    
    # Deserialization
    decoded_team = dict(**json.loads(json_data.read()))
    print(decoded_team)
# Out:
# {'a': ['a', 'b']}

# %%
# %who
# Out:
# CSP_Seq2Seq	 DataLoader	 Dataset	 F	 ModNArithmeticGenerator	 SymbolicArithmeticDataset	 evaluate_seq	 focal_loss	 json
# load_checkpoint	 main	 math	 nn	 np	 os	 plot_grokking_analysis_f1	 plot_training_curves_f1	 plt
# random	 save_checkpoint	 setup_logging	 sys	 torch	 tqdm	 train_model_seq

# %%
print(dir())
# Out:
# ['CSP_Seq2Seq', 'DataLoader', 'Dataset', 'F', 'In', 'ModNArithmeticGenerator', 'Out', 'SymbolicArithmeticDataset', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__nonzero__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i2', '_i3', '_i4', '_ih', '_ii', '_iii', '_oh', 'evaluate_seq', 'exit', 'focal_loss', 'get_ipython', 'json', 'load_checkpoint', 'main', 'math', 'nn', 'np', 'open', 'os', 'plot_grokking_analysis_f1', 'plot_training_curves_f1', 'plt', 'quit', 'random', 'save_checkpoint', 'setup_logging', 'sys', 'torch', 'tqdm', 'train_model_seq']

# %%
for thread_id, frame in sys._current_frames().items():
    if 'main' in frame.f_code.co_name:
        print(frame.f_locals.keys())

# %%
print('experiment_results' in globals())
# Out:
# False

# %%
if main.__closure__:
    for i, cell in enumerate(main.__closure__):
        try:
            print(f"cell {i}: {cell.cell_contents}")
        except ValueError:
            print(f"cell {i}: empty")

# %%
print(dir(main))
# Out:
# ['__annotations__', '__builtins__', '__call__', '__class__', '__closure__', '__code__', '__defaults__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__get__', '__getattribute__', '__getstate__', '__globals__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__kwdefaults__', '__le__', '__lt__', '__module__', '__name__', '__ne__', '__new__', '__qualname__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__type_params__']

# %%
print(main.__closure__)
# Out:
# None

# %%
print('experiment_results' in globals())
print(globals().get('experiment_results', '没找到'))
# Out:
# False
# 没找到

# %%
print(main.__get__("experiment_results"))
# Out:
# <bound method main of 'experiment_results'>
