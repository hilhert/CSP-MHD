# %%
# %run sim_sequence.py
# Out:
# Using device: cuda
# 创建新模型
# 参数量: 119,177
# ...
# Evaluating:   1%|          | 3/313 [00:00<00:12, 23.88it/s]
# [Debug] Input: <SOS>(1 - 0 + (0 + 2)) mod 9 =
# [Debug] Pred : 1repeat(1 - 0 + (0 + 1)) mod 9 = 1
# [Debug] Target: 3repeat(1 - 0 + (0 + 2)) mod 9 = 3
# pred_ids[0]: [1, 20, 14, 1, 13, 11, 13, 0, 13, 10, 13, 14, 0, 13, 10, 13, 1, 15, 15, 13, 19, 13, 9, 13, 12, 13, 1, 17, 17, 1, 17, 19, 13, 13, 9, 13, 12, 13, 1, 17]
# ----------------------------------------
# [Debug] Input: <SOS>((2 + (3 + 4) + 6)) mod 9 =
# [Debug] Pred : 6repeat((2 + (3 + 4) + 1)) mod 9 = 6
# [Debug] Target: 6repeat((2 + (3 + 4) + 6)) mod 9 = 6
# pred_ids[0]: [1, 20, 14, 1, 13, 11, 13, 0, 13, 10, 13, 14, 0, 13, 10, 13, 1, 15, 15, 13, 19, 13, 9, 13, 12, 13, 1, 17, 17, 1, 17, 19, 13, 13, 9, 13, 12, 13, 1, 17]
# ----------------------------------------
# [Debug] Input: <SOS>(1 + 3 - 3) mod 9 =
# [Debug] Pred : 1repeat(1 + 3 - (1 + 1)) mod
# [Debug] Target: 1repeat(1 + 3 - 3) mod 9 = 1
# ...
