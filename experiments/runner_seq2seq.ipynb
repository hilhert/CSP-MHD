# %%
# %run sim_sequence.py
# Out:
# Using device: cpu
# 创建新模型
# 参数量: 26,921
# ...
# Evaluating:  19%|█▉        | 6/32 [00:00<00:00, 28.20it/s]
# [Debug] Input: <SOS>2 - 2 - 0 mod 3 =
# [Debug] Pred : (0 - 1) mod 3 = 1
# [Debug] Target: 2 - 2 - 0 mod 3 = 0
# pred_ids[0]: [14, 0, 13, 11, 13, 1, 15, 13, 19, 13, 3, 13, 12, 13, 1, 17, 17, 13, 1, 17]
# ----------------------------------------
# [Debug] Input: <SOS>(2 - 0) mod 3 =
# [Debug] Pred : (0 - 1) mod 3 = 1
# [Debug] Target: (2 - 0) mod 3 = 2
# pred_ids[0]: [14, 0, 13, 11, 13, 1, 15, 13, 19, 13, 3, 13, 12, 13, 1, 17, 17, 13, 1, 17]
# ----------------------------------------
# [Debug] Input: <SOS>(2 + 0) mod 3 =
# [Debug] Pred : (0 - 1) mod 3 = 1
# [Debug] Target: (2 + 0) mod 3 = 2
# pred_ids[0]: [14, 0, 13, 11, 13, 1, 15, 13, 19, 13, 3, 13, 12, 13, 1, 17, 17, 13, 1, 17]
# ----------------------------------------
# [Debug] Input: <SOS>1 + 1 mod 3 =
# [Debug] Pred : (0 - 1) mod 3 =
# [Debug] Target: 1 + 1 mod 3 = 2
# ...
