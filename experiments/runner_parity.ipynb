# %%
# %run parity.py
# Out:
# Using device: cpu
# Parameters: 3,755
# Training:   0%|          | 1/300 [00:08<42:33,  8.54s/it]
# Epoch   0 | Loss: 0.6977 | Acc: 0.5275 | F1: 0.6733 | GradNorm: 0.4247 | Best_F1: 0.6733
# Training:   4%|▎         | 11/300 [01:04<27:11,  5.65s/it]
# Epoch  10 | Loss: 0.6842 | Acc: 0.5475 | F1: 0.2588 | GradNorm: 0.0581 | Best_F1: 0.6733
# Training:   7%|▋         | 21/300 [02:00<26:19,  5.66s/it]
# Epoch  20 | Loss: 0.0111 | Acc: 0.9975 | F1: 0.9975 | GradNorm: 0.1887 | Best_F1: 0.9975
# Training:  10%|█         | 31/300 [02:45<20:29,  4.57s/it]
# Epoch  30 | Loss: 0.0026 | Acc: 0.9975 | F1: 0.9975 | GradNorm: 5.1517 | Best_F1: 0.9975
# Training:  14%|█▎        | 41/300 [03:29<19:44,  4.57s/it]
# Epoch  40 | Loss: 0.0030 | Acc: 0.9990 | F1: 0.9990 | GradNorm: 0.3610 | Best_F1: 0.9990
# Training:  17%|█▋        | 51/300 [04:11<18:06,  4.36s/it]
# Epoch  50 | Loss: 0.0091 | Acc: 0.9975 | F1: 0.9975 | GradNorm: 0.0127 | Best_F1: 0.9990
# ...
