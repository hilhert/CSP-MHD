# %%
# %run parity.py
# Out:
# Using device: cpu
# Parameters: 3,560
# Training:   0%|          | 1/300 [00:03<18:34,  3.73s/it]
# Epoch   0 | Loss: 0.7036 | Acc: 0.5240 | F1: 0.1423 | GradNorm: 6.5176 | Best_F1: 0.1423
# Training:   4%|▎         | 11/300 [00:35<15:32,  3.23s/it]
# Epoch  10 | Loss: 0.6961 | Acc: 0.5160 | F1: 0.3564 | GradNorm: 13.1814 | Best_F1: 0.3564
# Training:   7%|▋         | 21/300 [01:08<15:39,  3.37s/it]
# Epoch  20 | Loss: 0.6955 | Acc: 0.5075 | F1: 0.1985 | GradNorm: 9.9163 | Best_F1: 0.3564
# Training:  10%|█         | 31/300 [01:40<14:51,  3.31s/it]
# Epoch  30 | Loss: 0.6949 | Acc: 0.4750 | F1: 0.5192 | GradNorm: 4.7765 | Best_F1: 0.5192
# Training:  14%|█▎        | 41/300 [02:13<14:37,  3.39s/it]
# Epoch  40 | Loss: 0.6963 | Acc: 0.5090 | F1: 0.3114 | GradNorm: 31.4027 | Best_F1: 0.5192
# Training:  17%|█▋        | 51/300 [02:48<14:53,  3.59s/it]
# Epoch  50 | Loss: 0.6950 | Acc: 0.4920 | F1: 0.4811 | GradNorm: 8.3756 | Best_F1: 0.5192
# ...
