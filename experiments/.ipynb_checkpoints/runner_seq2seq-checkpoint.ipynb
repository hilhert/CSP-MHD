# %%
# %run sim_sequence.py
# Out:
# Using device: cpu
# 参数量: 26,355
# Training: 100%|██████████| 313/313 [00:33<00:00,  9.33it/s]
# Evaluating:  28%|██▊       | 9/32 [00:00<00:00, 41.91it/s]
# [Debug] Input: <SOS>0 + 0 + 2 =
# [Debug] Pred : +++++++++++++
# [Debug] Target: 0 + 0 + 2 =
# ----------------------------------------
# [Debug] Input: <SOS>2 - 0 + 2 =
# [Debug] Pred : +++++++++++++
# [Debug] Target: 2 - 0 + 2 =
# ----------------------------------------
# [Debug] Input: <SOS>1 - 2 - 2 =
# [Debug] Pred : +++++++++++++
# [Debug] Target: 1 - 2 - 2 =
# ----------------------------------------
# [Debug] Input: <SOS>2 + 2 =
# [Debug] Pred : +++++++++
# [Debug] Target: 2 + 2 =
# ----------------------------------------
# [Debug] Input: <SOS>2 - 1 + 0 =
# [Debug] Pred : +++++++++++++
# [Debug] Target: 2 - 1 + 0 =
# ----------------------------------------
# Evaluating: 100%|██████████| 32/32 [00:01<00:00, 31.98it/s]
# Epoch 1: Loss=0.5785, Acc=0.0000
# Training: 100%|██████████| 313/313 [00:31<00:00,  9.86it/s]
# Evaluating:  25%|██▌       | 8/32 [00:00<00:00, 39.07it/s]
# [Debug] Input: <SOS>0 + 0 + 2 =
# [Debug] Pred : +++++++++++++
# [Debug] Target: 0 + 0 + 2 =
# ----------------------------------------
# [Debug] Input: <SOS>2 - 0 + 2 =
# [Debug] Pred : +++++++++++++
# [Debug] Target: 2 - 0 + 2 =
# ----------------------------------------
# [Debug] Input: <SOS>1 - 2 - 2 =
# [Debug] Pred : -------------
# [Debug] Target: 1 - 2 - 2 =
# ----------------------------------------
# [Debug] Input: <SOS>2 + 2 =
# [Debug] Pred :
# [Debug] Target: 2 + 2 =
# ----------------------------------------
# [Debug] Input: <SOS>2 - 1 + 0 =
# [Debug] Pred : +++++++++++++
# [Debug] Target: 2 - 1 + 0 =
# ----------------------------------------
# Evaluating: 100%|██████████| 32/32 [00:01<00:00, 24.81it/s]
# Epoch 2: Loss=0.0677, Acc=0.0000
# Training: 100%|██████████| 313/313 [00:32<00:00,  9.69it/s]
# Evaluating:  31%|███▏      | 10/32 [00:00<00:00, 45.27it/s]
# [Debug] Input: <SOS>0 + 0 + 2 =
# [Debug] Pred : +++++++++++++
# [Debug] Target: 0 + 0 + 2 =
# ----------------------------------------
# [Debug] Input: <SOS>2 - 0 + 2 =
# [Debug] Pred : +++++++++++++
# [Debug] Target: 2 - 0 + 2 =
# ----------------------------------------
# [Debug] Input: <SOS>1 - 2 - 2 =
# [Debug] Pred : -------------
# [Debug] Target: 1 - 2 - 2 =
# ----------------------------------------
# [Debug] Input: <SOS>2 + 2 =
# [Debug] Pred : ---------
# [Debug] Target: 2 + 2 =
# ----------------------------------------
# [Debug] Input: <SOS>2 - 1 + 0 =
# [Debug] Pred : +++++++++++++
# [Debug] Target: 2 - 1 + 0 =
# ----------------------------------------
# Evaluating: 100%|██████████| 32/32 [00:00<00:00, 35.54it/s]
# Epoch 3: Loss=0.0190, Acc=0.0000
# Training: 100%|██████████| 313/313 [00:35<00:00,  8.84it/s]
# Evaluating:  22%|██▏       | 7/32 [00:00<00:00, 33.47it/s]
# [Debug] Input: <SOS>0 + 0 + 2 =
# [Debug] Pred : +++++++++++++
# [Debug] Target: 0 + 0 + 2 =
# ----------------------------------------
# [Debug] Input: <SOS>2 - 0 + 2 =
# [Debug] Pred : +++++++++++++
# [Debug] Target: 2 - 0 + 2 =
# ----------------------------------------
# [Debug] Input: <SOS>1 - 2 - 2 =
# [Debug] Pred : +++++++++++++
# [Debug] Target: 1 - 2 - 2 =
# ----------------------------------------
# [Debug] Input: <SOS>2 + 2 =
# [Debug] Pred :
# [Debug] Target: 2 + 2 =
# ----------------------------------------
# [Debug] Input: <SOS>2 - 1 + 0 =
# [Debug] Pred : +++++++++++++
# [Debug] Target: 2 - 1 + 0 =
# ----------------------------------------
# Evaluating: 100%|██████████| 32/32 [00:01<00:00, 23.38it/s]
# Epoch 4: Loss=0.0083, Acc=0.0000
# Training:  13%|█▎        | 40/313 [00:04<00:31,  8.56it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/notebook/state_propagate/experiments/sim_sequence.py:95
#      78 '''
#      79     losses, f1s,accs,grad_norms = train_model(
#      80         model, train_loader, test_loader,weight_decay=1e-4,
#    (...)
#      91     print(f"Log: {log_file}")
#      92 '''
#      94 if __name__ == "__main__":
# ---> 95     main()
#
# File ~/notebook/state_propagate/experiments/sim_sequence.py:71, in main()
#      69 epochs = 50
#      70 for epoch in range(epochs):
# ---> 71     loss = train_model_seq(model, train_loader, optimizer, criterion, device, pad_idx)
#      72     acc = evaluate_seq(model, test_loader, device, pad_idx, eos_idx,debug=True)
#      73     print(f"Epoch {epoch+1}: Loss={loss:.4f}, Acc={acc:.4f}")
#
# File ~/notebook/state_propagate/utils/train.py:264, in train_model_seq(model, train_loader, optimizer, criterion, device, pad_idx)
#     262 loss = (loss * mask.float()).sum() / mask.sum()
#     263 optimizer.zero_grad()
# --> 264 loss.backward()
#     265 torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
#     266 optimizer.step()
#
# File ~/桌面/State_Propation/.venv/lib/python3.10/site-packages/torch/_tensor.py:623, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     613 if has_torch_function_unary(self):
#     614     return handle_torch_function(
#     615         Tensor.backward,
#     616         (self,),
#    (...)
#     621         inputs=inputs,
#     622     )
# --> 623 torch.autograd.backward(
#     624     self, gradient, retain_graph, create_graph, inputs=inputs
#     625 )
#
# File ~/桌面/State_Propation/.venv/lib/python3.10/site-packages/torch/autograd/__init__.py:395, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     390     retain_graph = create_graph
#     392 # The reason we repeat the same comment below is that
#     393 # some Python versions print out the first line of a multi-line function
#     394 # calls in the traceback and some print out the last line
# --> 395 _engine_run_backward(
#     396     tensors,
#     397     grad_tensors_,
#     398     retain_graph,
#     399     create_graph,
#     400     inputs_tuple,
#     401     allow_unreachable=True,
#     402     accumulate_grad=True,
#     403 )
#
# File ~/桌面/State_Propation/.venv/lib/python3.10/site-packages/torch/autograd/graph.py:979, in _engine_run_backward(t_outputs, *args, **kwargs)
#     976 torch._C._stash_obj_in_tls("context", contextvars.copy_context())
#     978 try:
# --> 979     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     980         t_outputs, *args, **kwargs
#     981     )  # Calls into the C++ engine to run the backward pass
#     982 finally:
#     983     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
import torch
import sys
sys.path.insert(0, '..')  # 如果 csp 在上一级目录

from csp.model import CSP_Seq2Seq
from csp.data import SymbolicArithmeticDataset, generate_arithmetic_sequence

# 1. 加载词表
dummy_dataset = SymbolicArithmeticDataset(1, generate_expression_func=generate_arithmetic_sequence)
vocab_size = dummy_dataset.vocab_size
char2idx = dummy_dataset.char2idx
idx2char = dummy_dataset.idx2char

# 2. 加载模型
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CSP_Seq2Seq(vocab_size, hidden_dim=64, num_layers=3).to(device)
model.load_state_dict(torch.load('csp_symbolic.pt', map_location=device))
model.eval()

# 3. 测试
sos_idx = char2idx['<SOS>']
eos_idx = char2idx['<EOS>']
pad_idx = char2idx['<PAD>']

def generate(model, input_str, max_len=20, temperature=1.0):
    input_ids = [char2idx[c] for c in input_str] + [eos_idx]
    input_tensor = torch.tensor(input_ids, dtype=torch.long).unsqueeze(0).to(device)
    
    # 编码
    x = model.embedding(input_tensor)
    h = torch.tanh(model.encoder_proj(x))
    h_real, h_imag = h, torch.zeros_like(h)
    for layer in model.layers:
        h_real, h_imag = layer(h_real, h_imag)
    h_real_last, h_imag_last = h_real[:, -1, :], h_imag[:, -1, :]
    
    outputs = []
    h_real_dec, h_imag_dec = h_real_last, h_imag_last
    current_token = torch.full((1,), sos_idx, device=device, dtype=torch.long)
    
    for _ in range(max_len):
        emb = model.embedding(current_token)
        emb_hidden = torch.tanh(model.encoder_proj(emb))
        h_real_dec = h_real_dec + emb_hidden
        h_imag_dec = h_imag_dec + emb_hidden
        phase = torch.atan2(h_imag_dec, h_real_dec + 1e-8)
        h_cos, h_sin = torch.cos(phase), torch.sin(phase)
        h_phasor = torch.cat([h_cos, h_sin], dim=-1)
        emb_out = torch.tanh(model.decoder_proj(h_phasor))
        logits = model.output_proj(emb_out)  # [1, vocab_size]
        
        # ★ 采样解码（温度控制）
        if temperature > 0:
            probs = torch.softmax(logits / temperature, dim=-1)
            next_token = torch.multinomial(probs, 1).squeeze()
        else:
            # 贪心解码（temperature=0）
            next_token = torch.argmax(logits, dim=-1)
        
        outputs.append(next_token)
        if next_token == eos_idx:
            break
        current_token = next_token
    
    if not outputs:
        return []
    return torch.cat(outputs, dim=0).tolist()

examples = ["5 + 3 = ", "12 + 7 = ", "9 - 4 = ", "15 - 3 = "]
for inp in examples:
    # 低温度（0.8）——更保守，接近 argmax
    pred_ids = generate(model, inp, temperature=0.8)
    pred_str = ''.join([idx2char[i] for i in pred_ids if i not in [pad_idx, sos_idx, eos_idx]])
    print(f"{inp} -> {pred_str}")

# 高温度（1.2）——更随机，输出更多样
for inp in examples:
    pred_ids = generate(model, inp, temperature=1.2)
    pred_str = ''.join([idx2char[i] for i in pred_ids if i not in [pad_idx, sos_idx, eos_idx]])
    print(f"{inp} (T=1.2) -> {pred_str}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       3 sys.path.insert(0, '..')  # 如果 csp 在上一级目录
#       5 from csp.model import CSP_Seq2Seq
# ----> 6 from csp.data import SymbolicArithmeticDataset, generate_arithmetic_sequence
#       8 # 1. 加载词表
#       9 dummy_dataset = SymbolicArithmeticDataset(1, generate_expression_func=generate_arithmetic_sequence)
#
# ImportError: cannot import name 'generate_arithmetic_sequence' from 'csp.data' (/home/lixiaohe/notebook/state_propagate/experiments/../csp/data.py)
