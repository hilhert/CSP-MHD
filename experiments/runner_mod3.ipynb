# %%
# %run mod3.py
# Out:
# Using device: cpu
# Parameters: 458
# Training:   0%|          | 1/300 [00:03<16:38,  3.34s/it]
# Epoch   0 | Loss: 0.6425 | Acc: 0.6615 | F1: 0.7963 | GradNorm: 0.9871 | Best_F1: 0.7963
# Training:   4%|▎         | 11/300 [00:30<14:01,  2.91s/it]
# Epoch  10 | Loss: 0.6364 | Acc: 0.6615 | F1: 0.7963 | GradNorm: 0.1850 | Best_F1: 0.7963
# Training:   7%|▋         | 21/300 [00:58<13:15,  2.85s/it]
# Epoch  20 | Loss: 0.6353 | Acc: 0.6615 | F1: 0.7963 | GradNorm: 0.4482 | Best_F1: 0.7963
# Training:  10%|█         | 31/300 [01:26<12:55,  2.88s/it]
# Epoch  30 | Loss: 0.6359 | Acc: 0.6615 | F1: 0.7963 | GradNorm: 1.0577 | Best_F1: 0.7963
# Training:  14%|█▎        | 41/300 [01:54<12:32,  2.91s/it]
# Epoch  40 | Loss: 0.6360 | Acc: 0.6615 | F1: 0.7963 | GradNorm: 18.2512 | Best_F1: 0.7963
# Training:  17%|█▋        | 51/300 [02:22<12:10,  2.93s/it]
# Epoch  50 | Loss: 0.6375 | Acc: 0.6615 | F1: 0.7963 | GradNorm: 5.8850 | Best_F1: 0.7963
# ...
