# %%
# %run mod3.py
# Out:
# Using device: cpu
# Parameters: 3,755
# Training:   0%|          | 1/300 [00:04<23:46,  4.77s/it]
# Epoch   0 | Loss: 0.6446 | Acc: 0.6850 | F1: 0.8131 | GradNorm: 0.6352 | Best_F1: 0.8131
# Training:   4%|▎         | 11/300 [00:46<20:43,  4.30s/it]
# Epoch  10 | Loss: 0.5437 | Acc: 0.6850 | F1: 0.8131 | GradNorm: 28.1155 | Best_F1: 0.8131
# Training:   7%|▋         | 21/300 [01:31<21:41,  4.66s/it]
# Epoch  20 | Loss: 0.4783 | Acc: 0.8675 | F1: 0.9118 | GradNorm: 19.2107 | Best_F1: 0.9118
# Training:  10%|█         | 31/300 [02:17<23:07,  5.16s/it]
# Epoch  30 | Loss: 0.2471 | Acc: 0.9970 | F1: 0.9978 | GradNorm: 22.4456 | Best_F1: 0.9978
# Training:  14%|█▎        | 41/300 [03:03<21:26,  4.97s/it]
# Epoch  40 | Loss: 0.0562 | Acc: 0.9970 | F1: 0.9978 | GradNorm: 2.6118 | Best_F1: 0.9978
# Training:  17%|█▋        | 51/300 [03:52<19:25,  4.68s/it]
# Epoch  50 | Loss: 0.0071 | Acc: 1.0000 | F1: 1.0000 | GradNorm: 0.5404 | Best_F1: 1.0000
# ...
